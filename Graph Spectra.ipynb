# %%
# %matplotlib notebook

# %%
from matplotlib import pyplot as plt
import h5py
import numpy as np
import json
import os
from datetime import datetime, timedelta
import re
import fnmatch
import dtools as dt

# %%
import sys
sys.path.append("C:\\Users\\c2\\Desktop\\Python")

# %%
date="2017-08-18"
file="_Hypres_spectra"
stamp = "105035"
num = '4'
conversion = 9
os.chdir("\\\\SAMBASHARE\\labshare\\data\\Cactus-PC\\experiments\\"
             + "2017-08-09" + "" + file + "\\" + date)

m=dt.loadMeasurement(date + "_" + stamp + "_SQUIDSpectrum.h5")

fig, ax = plt.subplots(figsize=(4,4))
ax.loglog(m.data.f, m.data.psdAve / conversion, color = "blue")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Power Spectral Density ($\phi_o$/Hz)")
plt.title("Hypres washer SQUID #" +num + " R16 (16Ohm Damp)" + "\n" + 
          m.config.timestamp)
ax.annotate("SQUID Bias " + str(m.config.squidarray.get("SQUID bias")) 
            + "\n" + "Array Bias " + str(m.config.squidarray.get("Array bias")) 
            , xy=(1, 1), xycoords='axes fraction', fontsize=10,
            xytext=(-5, -5), textcoords='offset points',
            ha='right', va='top')
# ax.annotate("Peaks at 1.6Hz, 25Hz, 60Hz"
#             , xy=(0, 0), xycoords='axes fraction', fontsize=10,
#             xytext=(5, 5), textcoords='offset points',
#             ha='left', va='bottom')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">
