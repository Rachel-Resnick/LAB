# %%
from matplotlib import pyplot as plt

# %%
import sys

# %%
sys.path.append("C:\\Users\\c2\\Desktop")
sys.path.append("C:\\Users\\c2\\Documents")

# %%
from Python import squid_plotting as squid
from Python import dtools as dt

# %%
squid.makePlots('113', '2017-02-20', '_squid_testing_113-116', iv='110143' , mod='114102', field=['123213','125106','123815'])
