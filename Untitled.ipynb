# %%
from matplotlib import pyplot as plt
import h5py
import numpy as np
import json
import os
from datetime import datetime, timedelta
import re
import fnmatch
from Python import dtools as dt

# %%
# %matplotlib notebook

# %%
import sys
sys.path.append("C:\\Users\\c2\\Desktop")
sys.path.append("C:\\Users\\c2\\Documents")

# %%
    os.chdir("\\\\SAMBASHARE\\labshare\\data\\Cactus-PC\\experiments\\2017-06-22_hypres_washer\\2017-06-22")
    date = "2017-06-22"
    timestamp = "180102"
    m = dt.loadMeasurement(date+'_' + timestamp +'_Mod2D.h5')
    fig, ax = plt.subplots(figsize=(5,4))
    Isquid = np.arange(-.000060, .00005999999999, 5e-7)
    X,Y = np.meshgrid(Isquid, m.data.Imod)
    v = m.data.V * 10e-6
    im=ax.pcolor(X, Y, v, cmap="RdBu")
    plt.ylabel('Mod Coil Current (mA)')
    plt.xlabel('Bias Current ($\mu$A)')
    cbar = fig.colorbar(im)
    cbar.set_label("SQUID voltage ($\mu$V)")
# Out:
# <img src="data:image/png;base64,..." width="500">
